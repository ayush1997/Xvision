# %% [markdown]
# ### Loading datas.json

# %%
import json
from pprint import pprint

dic = {}
with open('datas.json') as data_file:
    data = json.load(data_file)
    lst = []
    n=0
    print len(data)
    for  i in data:
        # print i
        dic[i] = "/".join(data[i]['items'])
# Out:
# 7469

# %% [markdown]
# ### Labeling the data and forming a distionary

# %%
c=0
st=""
new_dict={}
check = ["normal","opacity", "cardiomegaly","calcinosis", "lung/hypoinflation","calcified granuloma","thoracic vertebrae/degenerative", "lung/hyperdistention", "spine/degenerative ","catheters, indwelling", "granulomatous disease", "nodule","surgical instruments","scoliosis", "spondylosis"]
for j in dic:
#     print dic[j]
    #     st = st + j
    for i in check:

        if i in dic[j].lower():
            st+=i
#             if i=="nodule":
#                 st="nodule"
#                 break
        
    if st == "":
        st += "missing"
    new_dict[j] = st
    
    st=""
    
#     if "opacity" in dic[j].lower():
#         print dic[j].lower()
#         c+=1
# print c
# print new_dict
# Out:
# {u'5988': 'missing', u'5989': 'opacity', u'5982': 'normal', u'5983': 'normal', u'5980': 'normal', u'5981': 'normal', u'5986': 'lung/hypoinflation', u'5987': 'missing', u'5984': 'missing', u'5985': 'missing', u'6796': 'lung/hypoinflationcatheters, indwelling', u'6797': 'opacitycatheters, indwelling', u'6794': 'lung/hypoinflation', u'6795': 'lung/hypoinflationcatheters, indwelling', u'6792': 'missing', u'6793': 'lung/hypoinflation', u'6790': 'normal', u'6791': 'missing', u'6798': 'opacitycatheters, indwelling', u'6799': 'normal', u'270': 'calcified granuloma', u'271': 'calcified granuloma', u'272': 'catheters, indwelling', u'273': 'catheters, indwelling', u'274': 'opacitycalcified granuloma', u'275': 'opacitycalcified granuloma', u'276': 'lung/hyperdistention', u'277': 'lung/hyperdistention', u'278': 'opacitynodule', u'279': 'opacitynodule', u'1370': 'nodule', u'1373': 'lung/hypoinflation', u'2143': 'nodule', u'2142': 'cardiomegalylung/hypoinflation', u'3519': 'opacitycalcinosislung/hypoinflation', u'3518': 'opacitycalcinosislung/hypoinflation', u'3513': 'normal', u'3512': 'normal', u'3511': 'normal', u'3510': 'normal', u'3517': 'calcified granuloma', u'3516': 'calcified granuloma', u'3515': 'normal', u'3514': 'normal', u'2688': 'opacitycalcified granuloma', u'2689': 'opacitycalcified granuloma', u'2684': 'normal', u'2685': 'normal', u'2686': 'nodule', u'2687': 'nodule', u'2680': 'calcinosis', u'2681': 'missing', u'2682': 'normal', u'2683': 'normal', u'99': 'lung/hyperdistention', u'98': 'lung/hyperdistention', u'91': 'calcinosisgranulomatous disease', u'90': 'calcinosisgranulomatous disease', u'93': 'missing', u'92': 'missing', u'95': 'normal', u'94': 'normal', u'97': 'missing', u'96': 'missing', u'1177': 'thoracic vertebrae/degenerative', u'1176': 'thoracic vertebrae/degenerative', u'1175': 'missing', u'1174': 'missing', u'1173': 'normal', u'1172': 'lung/hypoinflation', u'1171': 'lung/hypoinflation', u'1170': 'missing', u'1179': 'opacitycalcinosislung/hyperdistentiongranulomatous diseasenodulesurgical instruments', u'1178': 'surgical instruments', u'1610': 'normal', u'7188': 'missing', u'7189': 'normal', u'877': 'normal', u'7180': 'normal', u'7181': 'normal', u'7182': 'missing', u'7183': 'missing', u'7184': 'missing', u'7185': 'missing', u'7186': 'normal', u'7187': 'missing', u'623': 'lung/hypoinflationscoliosis', u'875': 'normal', u'622': 'normal', u'872': 'cardiomegalycalcinosis', u'1225': 'normal', u'873': 'cardiomegalycalcinosis', u'620': 'normal', u'870': 'normal', u'627': 'normal', u'871': 'normal', u'626': 'normal', u'7456': 'thoracic vertebrae/degenerative', u'7457': 'opacity', u'7454': 'calcinosisthoracic vertebrae/degenerative', u'7455': 'thoracic vertebrae/degenerative', u'7452': 'normal', u'7453': 'calcinosisthoracic vertebrae/degenerative', u'7450': 'missing', u'2740': 'cardiomegaly', u'624': 'lung/hypoinflationscoliosis', u'4590': 'normal', u'7458': 'opacity', u'7459': 'normal', u'4591': 'normal', u'2745': 'calcinosis', u'4597': 'normal', u'2747': 'scoliosisspondylosis', u'4595': 'normal', u'2749': 'normal', u'4845': 'cardiomegaly', u'4598': 'missing', u'4847': 'lung/hyperdistention', u'4734': 'opacity', u'4735': 'lung/hypoinflation', u'2039': 'cardiomegaly', u'4843': 'normal', u'4738': 'opacitycatheters, indwellingsurgical instruments', u'4739': 'opacitycatheters, indwellingsurgical instruments', u'1987': 'missing', u'393': 'surgical instruments', u'392': 'normal', u'391': 'thoracic vertebrae/degenerativegranulomatous disease', u'390': 'thoracic vertebrae/degenerativegranulomatous disease', u'397': 'missing', u'396': 'calcified granuloma', u'395': 'calcified granuloma', u'394': 'surgical instruments', u'399': 'normal', u'398': 'missing', u'2309': 'missing', u'2308': 'missing', u'4729': 'normal', u'4728': 'normal', u'4725': 'surgical instruments', u'2300': 'normal', u'4727': 'normal', u'2302': 'opacity', u'2305': 'calcinosisnodule', u'2304': 'calcinosisnodule', u'4723': 'normal', u'4722': 'normal', u'5847': 'miss ...

# %% [markdown]
# ### Calculate unique combinations of above diseases

# %%
from collections import Counter
c = Counter( (new_dict.values()) )

# print c.items()
c.items().sort(key=lambda x: x[0])
c = dict(c)
print len(c)
# Out:
# 187

# %% [markdown]
# ### The dictionary is sorted according to number of cases in each disease.

# %%
from operator import itemgetter
sort = sorted(c.items(), key=itemgetter(1))
print sort[-40:]
# print sort
# Out:
# [('opacitynodule', 11), ('lung/hypoinflationcatheters, indwelling', 12), ('granulomatous diseasespondylosis', 12), ('cardiomegalysurgical instruments', 12), ('thoracic vertebrae/degenerativelung/hyperdistention', 16), ('calcified granulomalung/hyperdistention', 16), ('lung/hypoinflationsurgical instruments', 17), ('opacitycatheters, indwelling', 17), ('calcinosisthoracic vertebrae/degenerative', 19), ('cardiomegalycatheters, indwelling', 19), ('opacitythoracic vertebrae/degenerative', 20), ('opacitycalcinosis', 21), ('calcinosislung/hyperdistention', 21), ('cardiomegalythoracic vertebrae/degenerative', 25), ('lung/hypoinflationthoracic vertebrae/degenerative', 27), ('calcinosisnodule', 29), ('calcinosisgranulomatous disease', 30), ('opacitylung/hyperdistention', 31), ('calcified granulomathoracic vertebrae/degenerative', 34), ('opacitycalcified granuloma', 35), ('cardiomegalycalcinosis', 37), ('calcinosiscalcified granuloma', 46), ('granulomatous disease', 58), ('cardiomegalylung/hypoinflation', 60), ('nodule', 69), ('opacitylung/hypoinflation', 72), ('spondylosis', 72), ('surgical instruments', 86), ('opacitycardiomegaly', 94), ('scoliosis', 102), ('catheters, indwelling', 112), ('calcinosis', 166), ('lung/hyperdistention', 210), ('thoracic vertebrae/degenerative', 238), ('lung/hypoinflation', 249), ('calcified granuloma', 263), ('cardiomegaly', 271), ('opacity', 374), ('missing', 1255), ('normal', 2697)]

# %%
labels = sorted([i for i in sort[-4:] if i[0]!="missing"], key=lambda x: x[1])
print labels
# Out:
# [('cardiomegaly', 271), ('opacity', 374), ('normal', 2697)]

# %% [markdown]
# ### Dictionary with list of indexes of every disease.

# %%
from collections import defaultdict

index_list = defaultdict(list)

for key, value in new_dict.iteritems():
    index_list[value].append(key)

# %% [markdown]
# ### Training and testing dictionary are made with label required.

# %%
train_images_dict = {}
test_images_dict={}
for  i in index_list:
#     print i
    if i== "normal":
        train_images_dict["normal"]=index_list[i][400:500]
        test_images_dict["normal"] = index_list[i][500:550]
#     elif i=="opacity":
#         train_images_dict["abnormal"]=index_list[i][:354]
#         test_images_dict["abnormal"] = index_list[i][354:374]
#     elif i=="cardiomegaly":
#         train_images_dict["abnormal"]=index_list[i][:251]
#         test_images_dict["abnormal"] = index_list[i][251:266]
#     elif i=="lung/hypoinflation":
#         train_images_dict["abnormal"]=index_list[i][:229]
#         test_images_dict["abnormal"] = index_list[i][229:249]
#     elif i=="calcified granuloma":
#         train_images_dict["abnormal"]+=index_list[i][:243]
#         test_images_dict["abnormal"] += index_list[i][243:263]
#     elif i=="thoracic vertebrae/degenerative":
#         train_images_dict["abnormal"]+=index_list[i][:218]
#         test_images_dict["abnormal"] += index_list[i][218:238]
#     elif i=="lung/hyperdistention":
#         train_images_dict["abnormal"]+=index_list[i][:190]
#         test_images_dict["abnormal"] += index_list[i][190:210]
#     elif i=="surgical instruments":
#         train_images_dict["abnormal"]+=index_list[i][:71]
#         test_images_dict["abnormal"] += index_list[i][71:86]
#     elif i=="catheters, indwelling":
#         train_images_dict["abnormal"]+=index_list[i][:100]
#         test_images_dict["abnormal"] += index_list[i][100:112] 
#     elif i=="calcinosis":
#         train_images_dict["abnormal"]+=index_list[i][:146]
#         test_images_dict["abnormal"] += index_list[i][146:166] 
    
    elif i=="nodule" :
        train_images_dict[i]=index_list[i][:54]
        test_images_dict[i] = index_list[i][49:]
    elif i=="calcinosisnodule":
        train_images_dict["nodule"]+=index_list[i][:23]
        test_images_dict["nodule"] += index_list[i][23:]

# %%
len(test_images_dict["normal"])
# Out:
# 50

# %% [markdown]
# ### Encoding the classes

# %%
# c=0
# label_dict = {}
# for i in labels[-1::-1]:
# #     print i[0]
#     label_dict[i[0]] = c
#     c+=1
label_dict = {"normal":0,"nodule":1}
print label_dict
# Out:
# {'nodule': 1, 'normal': 0}

# %%
import numpy as np
label_index={}
for i in label_dict:
    a = np.zeros(2)
    a[label_dict[i]]=1
    label_index[i] = a
print label_index
# Out:
# {'nodule': array([ 0.,  1.]), 'normal': array([ 1.,  0.])}

# %%
for i in label_index:
    print i
    print label_index[i]
# Out:
# nodule
# [ 0.  1.]
# normal
# [ 1.  0.]

# %%
new_image_dict={}
for i in new_dict:
    if new_dict[i] in label_index.keys():
        new_image_dict[i] = label_index[new_dict[i]]

# %%
new_image_dict={}
for i in new_dict:
    if new_dict[i] =="normal":
        new_image_dict[i] = np.array([1,0])
    else:
        new_image_dict[i] = np.array([0,1])

# %%
print len(new_image_dict)
# Out:
# 7469

# %%
import shutil,os
os.chdir('/home/ayush/Documents/xray')

# %%
#trainign image list
train_list=[]
test_list=[]
for  i in train_images_dict:
    train_list +=train_images_dict[i]
for  i in test_images_dict:
    test_list +=test_images_dict[i]
print len(train_list)
# Out:
# 177

# %%
from random import shuffle

shuffle(train_list)
shuffle(test_list)

# for  i in train_list:
#     print new_dict[i]
for i in train_list:
#     print new_dict[i]
# Out:
# normal
# normal
# nodule
# nodule
# normal
# nodule
# normal
# normal
# nodule
# normal
# calcinosisnodule
# nodule
# normal
# normal
# nodule
# normal
# nodule
# nodule
# normal
# normal
# calcinosisnodule
# nodule
# normal
# normal
# normal
# nodule
# normal
# normal
# normal
# calcinosisnodule
# calcinosisnodule
# normal
# nodule
# normal
# normal
# normal
# normal
# nodule
# normal
# normal
# normal
# normal
# nodule
# normal
# normal
# normal
# calcinosisnodule
# calcinosisnodule
# nodule
# normal
# nodule
# normal
# nodule
# nodule
# normal
# normal
# normal
# normal
# normal
# calcinosisnodule
# nodule
# nodule
# nodule
# normal
# calcinosisnodule
# normal
# nodule
# calcinosisnodule
# nodule
# normal
# normal
# nodule
# normal
# normal
# normal
# normal
# nodule
# calcinosisnodule
# nodule
# calcinosisnodule
# normal
# nodule
# normal
# calcinosisnodule
# nodule
# nodule
# normal
# normal
# nodule
# normal
# normal
# normal
# nodule
# normal
# normal
# calcinosisnodule
# normal
# calcinosisnodule
# normal
# normal
# normal
# nodule
# normal
# nodule
# nodule
# normal
# normal
# normal
# normal
# normal
# calcinosisnodule
# nodule
# nodule
# nodule
# normal
# calcinosisnodule
# nodule
# calcinosisnodule
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# nodule
# normal
# nodule
# nodule
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# nodule
# calcinosisnodule
# normal
# nodule
# nodule
# nodule
# nodule
# normal
# nodule
# normal
# calcinosisnodule
# normal
# nodule
# calcinosisnodule
# normal
# nodule
# normal
# nodule
# normal
# nodule
# calcinosisnodule
# normal
# normal
# nodule
# normal
# normal
# normal
# normal
# nodule
# nodule
# normal
# normal
# normal
# calcinosisnodule
# calcinosisnodule
# nodule
# normal

# %%
len(test_list)
# Out:
# 76

# %% [markdown]
# ### Folder with all training images is formed.

# %%
#copy training data
c=0
train_label={}

os.mkdir("/home/ayush/Documents/xray/DeepLearning/final_train_images_calc_nodule_only")
for i in train_list:
#     print i
    
    shutil.copy('/home/ayush/Documents/xray/DeepLearning/images/'+i+'.png', '/home/ayush/Documents/xray/DeepLearning/final_train_images_calc_nodule_only/'+str(c)+'.png')
    train_label[c] = new_image_dict[i]
    c+=1
# Out:
# 6451
# 2822
# 823
# 6810
# 878
# 1956
# 5208
# 3601
# 5265
# 4064
# 1559
# 3647
# 1328
# 4236
# 5502
# 4450
# 2371
# 3646
# 6331
# 3439
# 6700
# 4143
# 7297
# 3605
# 952
# 5263
# 1092
# 2038
# 1400
# 869
# 2501
# 590
# 2686
# 599
# 7296
# 445
# 5416
# 5902
# 5415
# 6457
# 4458
# 7292
# 1013
# 1463
# 5596
# 3431
# 6455
# 3672
# 5503
# 311
# 1370
# 954
# 822
# 1730
# 7120
# 6293
# 955
# 6450
# 1661
# 1700
# 4144
# 1323
# 1808
# 1405
# 1558
# 6330
# 4622
# 1699
# 6811
# 3049
# 4842
# 4691
# 4457
# 3602
# 3433
# 1542
# 1729
# 2800
# 5483
# 868
# 879
# 4693
# 4234
# 1737
# 1203
# 4578
# 4964
# 4214
# 3548
# 1099
# 596
# 4235
# 827
# 442
# 1091
# 2502
# 310
# 2674
# 4844
# 7293
# 6452
# 826
# 5780
# 4577
# 4928
# 4238
# 3296
# 4237
# 717
# 3957
# 2799
# 4893
# 2143
# 4892
# 3389
# 2305
# 3549
# 4972
# 5590
# 4063
# 591
# 2296
# 1662
# 3048
# 1660
# 5419
# 5482
# 443
# 7147
# 5264
# 444
# 3606
# 5209
# 5595
# 1329
# 3294
# 874
# 3434
# 3040
# 3041
# 1204
# 3673
# 4841
# 4692
# 6372
# 6373
# 5901
# 6292
# 1322
# 4594
# 6456
# 2297
# 4621
# 2673
# 4230
# 4927
# 3956
# 2687
# 4215
# 1371
# 2304
# 953
# 5418
# 2144
# 4212
# 1663
# 1406
# 4213
# 2372
# 1957
# 6459
# 6458
# 6909
# 867
# 6699
# 7148
# 4060

# %%
print len(train_label)
# Out:
# 177

# %% [markdown]
# ### Folder with all testing images in made

# %%
#copy teasting data
c=0
test_label={}
os.mkdir("/home/ayush/Documents/xray/DeepLearning/final_test_images_calc_nodule_only")
for i in test_list:
    shutil.copy('/home/ayush/Documents/xray/DeepLearning/images/'+i+'.png', '/home/ayush/Documents/xray/DeepLearning/final_test_images_calc_nodule_only/'+str(c)+'.png')
    test_label[c] = new_image_dict[i]
    c+=1

# %% [markdown]
# ### All the training and testing labels are stored as Pickled files.

# %%
import pickle
import numpy as np
filename = "training_labels_calc_nodule_only"
# filename = "testing_labels_calc_nodule_only"

fileObject = open(filename,'wb') 
pickle.dump(np.array(train_label.values()),fileObject)
fileObject.close()
